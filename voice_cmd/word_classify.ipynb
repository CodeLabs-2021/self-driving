# %%
'''
Machine learning algorithm takes audio FFT output
copied from Serial Monitor, pasted into CSV file,
then used to create ML model in a header file.
'''

import numpy as np
from glob import glob   
from os.path import basename

def load_features(folder):
    dataset = None
    classmap = {}
    for class_idx, filename in enumerate(glob('%s/*.csv' % folder)):
        class_name = basename(filename)[:-4]
        classmap[class_idx] = class_name
        samples = np.loadtxt(filename, dtype=float, delimiter=',')
        labels = np.ones((len(samples), 1)) * class_idx
        samples = np.hstack((samples, labels))
        dataset = samples if dataset is None else np.vstack((dataset, samples))

    return dataset, classmap

# %%
from sklearn.ensemble import RandomForestClassifier

def get_classifier(features):
    X, y = features[:, :-1], features[:, -1]

    return RandomForestClassifier(20, max_depth=10).fit(X, y)

# %%
from micromlgen import port

# Modify folder to the actual location of your csv files
if __name__ == '__main__':
    features, classmap = load_features('/your/csv/directory')
    classifier = get_classifier(features)
    c_code = port(classifier, classmap=classmap)
    print(c_code)
# Out:
# #pragma once
# #include <cstdarg>
# namespace Eloquent {
#     namespace ML {
#         namespace Port {
#             class RandomForest {
#                 public:
#                     /**
#                     * Predict class for features vector
#                     */
#                     int predict(float *x) {
#                         uint8_t votes[4] = { 0 };
#                         // tree #1
#                         if (x[1] <= 12.385000228881836) {
#                             if (x[11] <= 67.35000228881836) {
#                                 votes[3] += 1;
#                             }
#
#                             else {
#                                 votes[2] += 1;
#                             }
#                         }
#
#                         else {
#                             if (x[6] <= 32.8700008392334) {
#                                 if (x[25] <= 233.02000427246094) {
#                                     votes[2] += 1;
#                                 }
#
#                                 else {
#                                     if (x[62] <= 20.77999973297119) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[0] <= 24.199999809265137) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[45] <= 186.6050033569336) {
#                                     if (x[50] <= 93.88000106811523) {
#                                         if (x[18] <= 141.95999908447266) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[53] <= 68.97999954223633) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[32] <= 208.87999725341797) {
#                                             if (x[47] <= 156.06500244140625) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[57] <= 46.459999084472656) {
#                                                 if (x[33] <= 253.19500732421875) {
#                                                     votes[3] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[42] <= 184.79999542236328) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[56] <= 44.64999961853027) {
#                                         if (x[12] <= 105.2599983215332) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #2
#                         if (x[35] <= 146.80999755859375) {
#                             votes[2] += 1;
#                         }
#
#                         else {
#                             if (x[42] <= 249.4800033569336) {
#                                 if (x[45] <= 184.68000030517578) {
#                                     if (x[12] <= 124.9749984741211) {
#                                         if (x[33] <= 249.71500396728516) {
#                                             if (x[20] <= 153.49500274658203) {
#                                                 if (x[49] <= 107.21000289916992) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[2] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[51] <= 130.18000030517578) {
#                                                     if (x[16] <= 90.43999862670898) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[48] <= 163.05999755859375) {
#                                                 if (x[61] <= 24.505000114440918) {
#                                                     if (x[25] <= 210.3499984741211) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[7] <= 38.64500045776367) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[2] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[0] <= 23.119999885559082) {
#                                                     votes[2] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[13] <= 103.64500045776367) {
#                                         if (x[18] <= 118.83500289916992) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[42] <= 219.45000457763672) {
#                                             if (x[12] <= 79.59499740600586) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 votes[0] += 1;
#                             }
#                         }
#
#                         // tree #3
#                         if (x[31] <= 156.91000366210938) {
#                             if (x[3] <= 30.27999973297119) {
#                                 if (x[56] <= 44.84000015258789) {
#                                     if (x[35] <= 285.8400115966797) {
#                                         votes[3] += 1;
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#
#                             else {
#                                 votes[2] += 1;
#                             }
#                         }
#
#                         else {
#                             if (x[20] <= 166.2550048828125) {
#                                 if (x[18] <= 129.43499755859375) {
#                                     votes[2] += 1;
#                                 }
#
#                                 else {
#                                     if (x[54] <= 57.60499954223633) {
#                                         if (x[30] <= 236.7750015258789) {
#                                             if (x[24] <= 219.73500061035156) {
#                                                 votes[2] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[34] <= 216.375) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[54] <= 76.21000289916992) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[18] <= 187.24500274658203) {
#                                     if (x[58] <= 34.209999084472656) {
#                                         if (x[23] <= 256.27000427246094) {
#                                             if (x[9] <= 70.51499938964844) {
#                                                 if (x[9] <= 51.779998779296875) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[17] <= 143.3300018310547) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[17] <= 167.51499938964844) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             if (x[50] <= 129.82000350952148) {
#                                                 votes[3] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[35] <= 207.57999420166016) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[32] <= 162.91000366210938) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #4
#                         if (x[23] <= 133.83499908447266) {
#                             if (x[47] <= 185.29500579833984) {
#                                 votes[2] += 1;
#                             }
#
#                             else {
#                                 votes[1] += 1;
#                             }
#                         }
#
#                         else {
#                             if (x[6] <= 30.390000343322754) {
#                                 if (x[29] <= 154.27000427246094) {
#                                     votes[0] += 1;
#                                 }
#
#                                 else {
#                                     votes[2] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[9] <= 51.650001525878906) {
#                                     if (x[57] <= 23.670000076293945) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[4] <= 37.68499946594238) {
#                                             if (x[44] <= 232.7249984741211) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[35] <= 300.9149932861328) {
#                                         if (x[20] <= 170.99500274658203) {
#                                             if (x[62] <= 17.980000495910645) {
#                                                 if (x[54] <= 70.64500045776367) {
#                                                     votes[2] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[55] <= 38.72999954223633) {
#                                                     votes[3] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[28] <= 291.6750030517578) {
#                                                 if (x[30] <= 344.2200012207031) {
#                                                     if (x[11] <= 89.63500213623047) {
#                                                         votes[3] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[14] <= 111.34499740600586) {
#                                                             votes[3] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[15] <= 96.57500076293945) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #5
#                         if (x[20] <= 142.9199981689453) {
#                             if (x[53] <= 95.11499786376953) {
#                                 if (x[2] <= 30.074999809265137) {
#                                     votes[0] += 1;
#                                 }
#
#                                 else {
#                                     votes[2] += 1;
#                                 }
#                             }
#
#                             else {
#                                 votes[1] += 1;
#                             }
#                         }
#
#                         else {
#                             if (x[48] <= 64.96999931335449) {
#                                 if (x[53] <= 73.19000053405762) {
#                                     votes[1] += 1;
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[21] <= 210.9800033569336) {
#                                     if (x[43] <= 170.62999725341797) {
#                                         if (x[28] <= 244.03499603271484) {
#                                             if (x[25] <= 247.5250015258789) {
#                                                 votes[3] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[23] <= 232.2050018310547) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[48] <= 138.29000091552734) {
#                                                 if (x[33] <= 199.47000122070312) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[55] <= 52.625) {
#                                             if (x[28] <= 229.45499420166016) {
#                                                 if (x[41] <= 177.47000122070312) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[4] <= 29.09000015258789) {
#                                                 if (x[33] <= 206.93500518798828) {
#                                                     if (x[63] <= 19.84000015258789) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[2] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[14] <= 117.10000228881836) {
#                                         if (x[55] <= 47.58999824523926) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             if (x[44] <= 190.8499984741211) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[55] <= 58.53500175476074) {
#                                             if (x[31] <= 293.32999420166016) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #6
#                         if (x[6] <= 30.47000026702881) {
#                             if (x[57] <= 34.30500030517578) {
#                                 if (x[16] <= 132.35499572753906) {
#                                     votes[2] += 1;
#                                 }
#
#                                 else {
#                                     votes[1] += 1;
#                                 }
#                             }
#
#                             else {
#                                 votes[2] += 1;
#                             }
#                         }
#
#                         else {
#                             if (x[41] <= 308.0449981689453) {
#                                 if (x[42] <= 200.9699935913086) {
#                                     if (x[0] <= 24.0) {
#                                         if (x[6] <= 44.3799991607666) {
#                                             if (x[20] <= 200.8949966430664) {
#                                                 if (x[33] <= 330.7900085449219) {
#                                                     if (x[5] <= 50.46000099182129) {
#                                                         if (x[13] <= 115.06999969482422) {
#                                                             votes[2] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[31] <= 238.36499786376953) {
#                                                     if (x[30] <= 235.28500366210938) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[2] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[51] <= 84.61499786376953) {
#                                             if (x[16] <= 134.83500289916992) {
#                                                 if (x[20] <= 186.67000579833984) {
#                                                     votes[3] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[39] <= 163.16000366210938) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[28] <= 197.85499572753906) {
#                                         if (x[59] <= 31.93000030517578) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[9] <= 49.625) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[24] <= 198.25) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 votes[0] += 1;
#                             }
#                         }
#
#                         // tree #7
#                         if (x[8] <= 51.30999946594238) {
#                             if (x[25] <= 170.91000366210938) {
#                                 if (x[6] <= 35.505001068115234) {
#                                     votes[2] += 1;
#                                 }
#
#                                 else {
#                                     votes[3] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[2] <= 17.024999618530273) {
#                                     if (x[4] <= 24.675000190734863) {
#                                         votes[3] += 1;
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[36] <= 305.4250030517578) {
#                                         if (x[61] <= 30.924999237060547) {
#                                             if (x[55] <= 55.80000114440918) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[55] <= 66.51499938964844) {
#                                                     if (x[3] <= 27.119999885559082) {
#                                                         votes[3] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 25.130000114440918) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[50] <= 107.59500122070312) {
#                                 if (x[46] <= 155.2699966430664) {
#                                     if (x[42] <= 182.10499572753906) {
#                                         votes[2] += 1;
#                                     }
#
#                                     else {
#                                         if (x[31] <= 183.8949966430664) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[23] <= 221.22500610351562) {
#                                         if (x[15] <= 93.28499603271484) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[42] <= 222.91500091552734) {
#                                     if (x[49] <= 113.6500015258789) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         votes[3] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[1] += 1;
#                                 }
#                             }
#                         }
#
#                         // tree #8
#                         if (x[48] <= 55.364999771118164) {
#                             votes[0] += 1;
#                         }
#
#                         else {
#                             if (x[28] <= 234.31499481201172) {
#                                 if (x[8] <= 66.08000183105469) {
#                                     if (x[33] <= 338.25) {
#                                         if (x[39] <= 153.95000457763672) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[35] <= 266.3999938964844) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[14] <= 74.07999801635742) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[59] <= 33.5) {
#                                     if (x[32] <= 202.38500213623047) {
#                                         if (x[35] <= 224.10499572753906) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             if (x[35] <= 254.72999572753906) {
#                                                 if (x[18] <= 194.9550018310547) {
#                                                     votes[2] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[33] <= 179.57500457763672) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             if (x[60] <= 38.81999969482422) {
#                                                 if (x[53] <= 43.41499900817871) {
#                                                     votes[3] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[4] <= 28.21500015258789) {
#                                                         if (x[57] <= 43.81999969482422) {
#                                                             votes[3] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[2] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[2] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 23.920000076293945) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[40] <= 234.31500244140625) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #9
#                         if (x[46] <= 160.94499969482422) {
#                             if (x[38] <= 268.8300018310547) {
#                                 if (x[62] <= 19.585000038146973) {
#                                     if (x[22] <= 229.22000122070312) {
#                                         if (x[26] <= 280.68499755859375) {
#                                             if (x[14] <= 147.93000030517578) {
#                                                 if (x[14] <= 110.88999938964844) {
#                                                     if (x[62] <= 19.050000190734863) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[36] <= 201.86499786376953) {
#                                             if (x[41] <= 198.08499908447266) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[56] <= 41.93499946594238) {
#                                         if (x[6] <= 35.89999961853027) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             if (x[34] <= 304.60499572753906) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[28] <= 268.8300018310547) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             if (x[1] <= 21.68000030517578) {
#                                                 votes[2] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[19] <= 182.61000061035156) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 votes[0] += 1;
#                             }
#                         }
#
#                         else {
#                             if (x[45] <= 169.26499938964844) {
#                                 if (x[33] <= 232.7949981689453) {
#                                     if (x[23] <= 260.06500244140625) {
#                                         votes[3] += 1;
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[2] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[4] <= 26.184999465942383) {
#                                     votes[1] += 1;
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#                         }
#
#                         // tree #10
#                         if (x[36] <= 182.2949981689453) {
#                             if (x[60] <= 24.204999923706055) {
#                                 votes[3] += 1;
#                             }
#
#                             else {
# ...
#
#                                                 else {
#                                                     votes[2] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[57] <= 37.02499961853027) {
#                                         if (x[59] <= 22.875) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[60] <= 19.735000610351562) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             votes[2] += 1;
#                         }
#
#                         // tree #18
#                         if (x[28] <= 307.7200012207031) {
#                             if (x[9] <= 49.375) {
#                                 if (x[7] <= 50.75) {
#                                     if (x[14] <= 97.31499862670898) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[2] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[16] <= 149.17499542236328) {
#                                     if (x[18] <= 210.0500030517578) {
#                                         if (x[37] <= 232.19499969482422) {
#                                             if (x[25] <= 184.06000518798828) {
#                                                 votes[3] += 1;
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[33] <= 288.01499938964844) {
#                                                 if (x[7] <= 41.64999961853027) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[28] <= 198.33999633789062) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[3] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[27] <= 275.8349914550781) {
#                                         if (x[35] <= 282.44000244140625) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[24] <= 286.4100036621094) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[15] <= 86.71000289916992) {
#                                 votes[0] += 1;
#                             }
#
#                             else {
#                                 votes[2] += 1;
#                             }
#                         }
#
#                         // tree #19
#                         if (x[24] <= 281.1449890136719) {
#                             if (x[36] <= 281.0800018310547) {
#                                 if (x[33] <= 245.73500061035156) {
#                                     if (x[18] <= 152.56500244140625) {
#                                         if (x[37] <= 223.80500030517578) {
#                                             if (x[28] <= 234.31499481201172) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[29] <= 189.76000213623047) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             if (x[9] <= 74.94499969482422) {
#                                                 if (x[2] <= 20.184999465942383) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[28] <= 264.94000244140625) {
#                                         if (x[55] <= 40.80500030517578) {
#                                             if (x[14] <= 66.26000022888184) {
#                                                 votes[2] += 1;
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[25] <= 240.2699966430664) {
#                                                 if (x[3] <= 21.94499969482422) {
#                                                     votes[2] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[38] <= 211.7100067138672) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[50] <= 96.16999816894531) {
#                                     votes[0] += 1;
#                                 }
#
#                                 else {
#                                     votes[1] += 1;
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[63] <= 28.079999923706055) {
#                                 if (x[42] <= 220.98999786376953) {
#                                     votes[2] += 1;
#                                 }
#
#                                 else {
#                                     votes[3] += 1;
#                                 }
#                             }
#
#                             else {
#                                 votes[0] += 1;
#                             }
#                         }
#
#                         // tree #20
#                         if (x[23] <= 111.46000289916992) {
#                             votes[2] += 1;
#                         }
#
#                         else {
#                             if (x[27] <= 220.0) {
#                                 if (x[58] <= 23.530000686645508) {
#                                     votes[0] += 1;
#                                 }
#
#                                 else {
#                                     if (x[40] <= 123.70000457763672) {
#                                         if (x[59] <= 27.05500030517578) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[63] <= 16.59999990463257) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             if (x[54] <= 80.5150032043457) {
#                                                 votes[2] += 1;
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[36] <= 230.9749984741211) {
#                                     if (x[6] <= 32.15000057220459) {
#                                         if (x[29] <= 179.41000366210938) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[61] <= 17.954999446868896) {
#                                             if (x[7] <= 47.55999946594238) {
#                                                 votes[3] += 1;
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[12] <= 88.14999771118164) {
#                                                 votes[2] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[46] <= 118.84000015258789) {
#                                         votes[3] += 1;
#                                     }
#
#                                     else {
#                                         if (x[17] <= 143.9250030517578) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             if (x[19] <= 176.77499389648438) {
#                                                 votes[3] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[19] <= 179.5199966430664) {
#                                                     votes[2] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // return argmax of votes
#                         uint8_t classIdx = 0;
#                         float maxVotes = votes[0];
#
#                         for (uint8_t i = 1; i < 4; i++) {
#                             if (votes[i] > maxVotes) {
#                                 classIdx = i;
#                                 maxVotes = votes[i];
#                             }
#                         }
#
#                         return classIdx;
#                     }
#
#                     /**
#                     * Predict readable class name
#                     */
#                     const char* predictLabel(float *x) {
#                         return idxToLabel(predict(x));
#                     }
#
#                     /**
#                     * Convert class idx to readable name
#                     */
#                     const char* idxToLabel(uint8_t classIdx) {
#                         switch (classIdx) {
#                             case 0:
#                             return "one";
#                             case 1:
#                             return "four";
#                             case 2:
#                             return "two";
#                             case 3:
#                             return "three";
#                             default:
#                             return "Houston we have a problem";
#                         }
#                     }
#
#                 protected:
#                 };
#             }
#         }
#     }
